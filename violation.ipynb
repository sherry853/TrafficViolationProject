# %%
class Violation:
  def __init__(self, driver_id,fine_amount, payment_status, month):
    self.driver_id = driver_id
    self.fine_amount = fine_amount
    self.payment_status = payment_status
    self.month = month
