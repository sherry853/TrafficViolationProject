# %%
# %run classes.ipynb

violations = [

    SpeedingViolation("D001", 67, 30, "Unpaid", 7),
    ParkingViolation("D001", 120, "Paid", 6),
    SignalJumpViolation("D001", 300, "Unpaid", 3),

    SpeedingViolation("D002", 180, 12, "Paid", 2),
    ParkingViolation("D002", 80, "Unpaid", 12),

    SignalJumpViolation("D003", 500, "Unpaid", 1),
    SpeedingViolation("D003", 220, 18, "Paid", 5),
    ParkingViolation("D003", 100, "Paid", 9),

    SpeedingViolation("D004", 250, 25, "Unpaid", 3),
    SignalJumpViolation("D004", 350, "Paid", 4),

    ParkingViolation("D005", 60, "Paid", 2),
    SpeedingViolation("D005", 150, 8, "Unpaid", 8),

    SignalJumpViolation("D006", 450, "Unpaid", 4),
    ParkingViolation("D006", 90, "Paid", 10),

    SpeedingViolation("D007", 300, 35, "Unpaid", 9),
    ParkingViolation("D007", 110, "Unpaid", 12),

    SignalJumpViolation("D008", 400, "Paid", 10),
    SpeedingViolation("D008", 175, 14, "Paid", 6),

    SpeedingViolation("D009", 120, 10, "Unpaid", 8),
    ParkingViolation("D009", 75, "Paid", 1),

    SpeedingViolation("D010", 500, 45, "Unpaid", 9),
    SignalJumpViolation("D010", 320, "Paid", 2),

    ParkingViolation("D011", 120, "Paid", 4),
    SpeedingViolation("D011", 210, 20, "Unpaid", 11),

    SignalJumpViolation("D012", 500, "Unpaid", 2),
    ParkingViolation("D012", 85, "Paid", 7),

    SpeedingViolation("D013", 200, 30, "Unpaid", 5),
    ParkingViolation("D013", 120, "Paid", 7),
    SignalJumpViolation("D013", 280, "Unpaid", 11),

    SignalJumpViolation("D014", 200, "Unpaid", 11),
    SpeedingViolation("D014", 140, 9, "Paid", 6),

    SpeedingViolation("D015", 400, 40, "Unpaid", 2),
    ParkingViolation("D015", 95, "Paid", 3),

    ParkingViolation("D016", 89, "Paid", 1),
    SignalJumpViolation("D016", 350, "Unpaid", 8),

    SignalJumpViolation("D017", 250, "Unpaid", 12),
    SpeedingViolation("D017", 160, 15, "Paid", 4),

    SpeedingViolation("D018", 275, 28, "Unpaid", 6),
    ParkingViolation("D018", 70, "Paid", 5),

    SignalJumpViolation("D019", 340, "Unpaid", 5),
    SpeedingViolation("D019", 190, 17, "Paid", 9),

    ParkingViolation("D020", 40, "Paid", 12),
    SignalJumpViolation("D020", 420, "Unpaid", 6),

    SpeedingViolation("D021", 330, 32, "Unpaid", 8),
    ParkingViolation("D021", 130, "Unpaid", 9),

    ParkingViolation("D022", 120, "Paid", 9),
    SignalJumpViolation("D022", 300, "Paid", 3),

    SignalJumpViolation("D023", 500, "Unpaid", 2),
    SpeedingViolation("D023", 230, 22, "Paid", 10),

    SpeedingViolation("D024", 350, 38, "Unpaid", 4),
    ParkingViolation("D024", 100, "Paid", 11),

]

def build_drivers_and_records(violation_list=None):
    if violation_list is None:
        violation_list = violations
 
    drivers: dict[str, Driver] = {}
    for v in violation_list:
        if v.driver_id not in drivers:
            drivers[v.driver_id] = Driver(v.driver_id)
        drivers[v.driver_id].add_violation(v)
 
    records = []
    for v in violation_list:
        row = v.to_dict()
        row["Number of Violations"] = drivers[v.driver_id].number_of_violations()
        records.append(row)
 
    return drivers, records
 
 
if __name__ == "__main__":
    drivers, records = build_drivers_and_records()
    print(f"Loaded {len(records)} violation records across {len(drivers)} drivers.")
    for r in records[:50]:
        print(r)
# Out:
# Loaded 51 violation records across 24 drivers.
# {'Driver ID': 'D001', 'Fine Amount': 67, 'Payment Status': 'Unpaid', 'Violation Month': 7, 'Violation Type': 'Speeding', 'Speed Over Limit': 30, 'Number of Violations': 3}
# {'Driver ID': 'D001', 'Fine Amount': 120, 'Payment Status': 'Paid', 'Violation Month': 6, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 3}
# {'Driver ID': 'D001', 'Fine Amount': 300, 'Payment Status': 'Unpaid', 'Violation Month': 3, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 3}
# {'Driver ID': 'D002', 'Fine Amount': 180, 'Payment Status': 'Paid', 'Violation Month': 2, 'Violation Type': 'Speeding', 'Speed Over Limit': 12, 'Number of Violations': 2}
# {'Driver ID': 'D002', 'Fine Amount': 80, 'Payment Status': 'Unpaid', 'Violation Month': 12, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D003', 'Fine Amount': 500, 'Payment Status': 'Unpaid', 'Violation Month': 1, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 3}
# {'Driver ID': 'D003', 'Fine Amount': 220, 'Payment Status': 'Paid', 'Violation Month': 5, 'Violation Type': 'Speeding', 'Speed Over Limit': 18, 'Number of Violations': 3}
# {'Driver ID': 'D003', 'Fine Amount': 100, 'Payment Status': 'Paid', 'Violation Month': 9, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 3}
# {'Driver ID': 'D004', 'Fine Amount': 250, 'Payment Status': 'Unpaid', 'Violation Month': 3, 'Violation Type': 'Speeding', 'Speed Over Limit': 25, 'Number of Violations': 2}
# {'Driver ID': 'D004', 'Fine Amount': 350, 'Payment Status': 'Paid', 'Violation Month': 4, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D005', 'Fine Amount': 60, 'Payment Status': 'Paid', 'Violation Month': 2, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D005', 'Fine Amount': 150, 'Payment Status': 'Unpaid', 'Violation Month': 8, 'Violation Type': 'Speeding', 'Speed Over Limit': 8, 'Number of Violations': 2}
# {'Driver ID': 'D006', 'Fine Amount': 450, 'Payment Status': 'Unpaid', 'Violation Month': 4, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D006', 'Fine Amount': 90, 'Payment Status': 'Paid', 'Violation Month': 10, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D007', 'Fine Amount': 300, 'Payment Status': 'Unpaid', 'Violation Month': 9, 'Violation Type': 'Speeding', 'Speed Over Limit': 35, 'Number of Violations': 2}
# {'Driver ID': 'D007', 'Fine Amount': 110, 'Payment Status': 'Unpaid', 'Violation Month': 12, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D008', 'Fine Amount': 400, 'Payment Status': 'Paid', 'Violation Month': 10, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D008', 'Fine Amount': 175, 'Payment Status': 'Paid', 'Violation Month': 6, 'Violation Type': 'Speeding', 'Speed Over Limit': 14, 'Number of Violations': 2}
# {'Driver ID': 'D009', 'Fine Amount': 120, 'Payment Status': 'Unpaid', 'Violation Month': 8, 'Violation Type': 'Speeding', 'Speed Over Limit': 10, 'Number of Violations': 2}
# {'Driver ID': 'D009', 'Fine Amount': 75, 'Payment Status': 'Paid', 'Violation Month': 1, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D010', 'Fine Amount': 500, 'Payment Status': 'Unpaid', 'Violation Month': 9, 'Violation Type': 'Speeding', 'Speed Over Limit': 45, 'Number of Violations': 2}
# {'Driver ID': 'D010', 'Fine Amount': 320, 'Payment Status': 'Paid', 'Violation Month': 2, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D011', 'Fine Amount': 120, 'Payment Status': 'Paid', 'Violation Month': 4, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D011', 'Fine Amount': 210, 'Payment Status': 'Unpaid', 'Violation Month': 11, 'Violation Type': 'Speeding', 'Speed Over Limit': 20, 'Number of Violations': 2}
# {'Driver ID': 'D012', 'Fine Amount': 500, 'Payment Status': 'Unpaid', 'Violation Month': 2, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D012', 'Fine Amount': 85, 'Payment Status': 'Paid', 'Violation Month': 7, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D013', 'Fine Amount': 200, 'Payment Status': 'Unpaid', 'Violation Month': 5, 'Violation Type': 'Speeding', 'Speed Over Limit': 30, 'Number of Violations': 3}
# {'Driver ID': 'D013', 'Fine Amount': 120, 'Payment Status': 'Paid', 'Violation Month': 7, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 3}
# {'Driver ID': 'D013', 'Fine Amount': 280, 'Payment Status': 'Unpaid', 'Violation Month': 11, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 3}
# {'Driver ID': 'D014', 'Fine Amount': 200, 'Payment Status': 'Unpaid', 'Violation Month': 11, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D014', 'Fine Amount': 140, 'Payment Status': 'Paid', 'Violation Month': 6, 'Violation Type': 'Speeding', 'Speed Over Limit': 9, 'Number of Violations': 2}
# {'Driver ID': 'D015', 'Fine Amount': 400, 'Payment Status': 'Unpaid', 'Violation Month': 2, 'Violation Type': 'Speeding', 'Speed Over Limit': 40, 'Number of Violations': 2}
# {'Driver ID': 'D015', 'Fine Amount': 95, 'Payment Status': 'Paid', 'Violation Month': 3, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D016', 'Fine Amount': 89, 'Payment Status': 'Paid', 'Violation Month': 1, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D016', 'Fine Amount': 350, 'Payment Status': 'Unpaid', 'Violation Month': 8, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D017', 'Fine Amount': 250, 'Payment Status': 'Unpaid', 'Violation Month': 12, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D017', 'Fine Amount': 160, 'Payment Status': 'Paid', 'Violation Month': 4, 'Violation Type': 'Speeding', 'Speed Over Limit': 15, 'Number of Violations': 2}
# {'Driver ID': 'D018', 'Fine Amount': 275, 'Payment Status': 'Unpaid', 'Violation Month': 6, 'Violation Type': 'Speeding', 'Speed Over Limit': 28, 'Number of Violations': 2}
# {'Driver ID': 'D018', 'Fine Amount': 70, 'Payment Status': 'Paid', 'Violation Month': 5, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D019', 'Fine Amount': 340, 'Payment Status': 'Unpaid', 'Violation Month': 5, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D019', 'Fine Amount': 190, 'Payment Status': 'Paid', 'Violation Month': 9, 'Violation Type': 'Speeding', 'Speed Over Limit': 17, 'Number of Violations': 2}
# {'Driver ID': 'D020', 'Fine Amount': 40, 'Payment Status': 'Paid', 'Violation Month': 12, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D020', 'Fine Amount': 420, 'Payment Status': 'Unpaid', 'Violation Month': 6, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D021', 'Fine Amount': 330, 'Payment Status': 'Unpaid', 'Violation Month': 8, 'Violation Type': 'Speeding', 'Speed Over Limit': 32, 'Number of Violations': 2}
# {'Driver ID': 'D021', 'Fine Amount': 130, 'Payment Status': 'Unpaid', 'Violation Month': 9, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D022', 'Fine Amount': 120, 'Payment Status': 'Paid', 'Violation Month': 9, 'Violation Type': 'Parking', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D022', 'Fine Amount': 300, 'Payment Status': 'Paid', 'Violation Month': 3, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D023', 'Fine Amount': 500, 'Payment Status': 'Unpaid', 'Violation Month': 2, 'Violation Type': 'Signal Jump', 'Speed Over Limit': 0, 'Number of Violations': 2}
# {'Driver ID': 'D023', 'Fine Amount': 230, 'Payment Status': 'Paid', 'Violation Month': 10, 'Violation Type': 'Speeding', 'Speed Over Limit': 22, 'Number of Violations': 2}
# {'Driver ID': 'D024', 'Fine Amount': 350, 'Payment Status': 'Unpaid', 'Violation Month': 4, 'Violation Type': 'Speeding', 'Speed Over Limit': 38, 'Number of Violations': 2}
